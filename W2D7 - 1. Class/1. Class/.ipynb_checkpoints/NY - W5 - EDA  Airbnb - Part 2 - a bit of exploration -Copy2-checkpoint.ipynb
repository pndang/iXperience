# %% [markdown]
# # <font color='#eb3483'> Exploratory Data Analysis - Part 2 </font>

# %% [markdown]
# Let's remind ourselves of where we left off

# %% [markdown]
# ### <font color='#eb3483'> Data processing steps </font>
# - There are xxx duplicate rows (we have removed them)
# - The variables `xxx, xxx, xxx and xxx` have missing values - what did we do with these?
# - The categorical variable `xxx, xxx` has a dominant class (65% of xxx are xxx, etc)
# - There are outliers in the variables `xxx and xxx` - what did we do with these?

# %% [markdown]
# ### <font color='#eb3483'> Entity Description <font color='#eb3483'>
#
# Here we describe the possible entities(groupings) that we can break our dataset into, this will help us think of different ways to slice and group the dataset in further steps.
#
# - 4 neighbourhood _groups
# - 38 neighbourhoods
# - Room_type -> hotels were the most frequent room type
# - Accommodates - > good range of sizes of properties.

# %%
# Importing the required packages here

import numpy as np
import pandas as pd
import seaborn as sns
import ast, json

from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### <font color='#eb3483'>  Load our data </font>
# After each step it is important to save the dataset with a different name (so we dont modify the original).

# %%
df = pd.read_csv("data/ny_airbnb_processed.csv")
df.head()
# Out:
#      id  host_id neighbourhood_group       neighbourhood  latitude  longitude  \
# 0  2595     2845           Manhattan             Midtown  40.75356  -73.98559
# 1  3831     4869            Brooklyn  Bedford-Stuyvesant  40.68494  -73.95765
# 2  5121     7356            Brooklyn  Bedford-Stuyvesant  40.68535  -73.95512
# 3  5136     7378            Brooklyn         Sunset Park  40.66265  -73.99454
# 4  5178     8967           Manhattan             Midtown  40.76457  -73.98317
#
#          room_type  accommodates  bathrooms  bedrooms  beds  price  \
# 0  Entire home/apt             2        NaN       NaN   1.0    150
# 1  Entire home/apt             3        NaN       1.0   3.0     79
# 2     Private room             2        NaN       1.0   1.0     60
# 3  Entire home/apt             4        NaN       2.0   2.0    175
# 4     Private room             2        NaN       1.0   1.0     61
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0              30                 48  2019-11-04               0.34
# 1               1                403  2021-05-04               5.16
# 2              30                 50  2016-06-05               0.56
# 3              21                  1  2014-01-02               0.01
# 4               2                474  2020-09-25               3.61
#
#    calculated_host_listings_count  availability_365  review_scores
# 0                               3             308.0           4.70
# 1                               1             208.0           4.46
# 2                               1             365.0           4.52
# 3                               1             134.0           5.00
# 4                               1             246.0           4.19

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <font color='#eb3483'> 4. Digging into patterns </font>
#
# The final stage of our EDA journey is going to be to look at the relationship between variables in our data. The goal of this stage is to get a better understanding of how our data interacts with each other.

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="700"/>
# </div>

# %% [markdown]
# ## <font color='#eb3483'> Multiple group counts </font>

# %%
def pivot_count(df, rows, columns): # this just makes a function that does a pivotcount for us with different variables.
    df_pivot = df.pivot_table(values="id", # could be any column, since we are just counting rows 
                              index=rows, 
                              columns=columns, 
                              aggfunc=np.size
                             ).dropna(axis=0, how='all')
    return df_pivot

# %%
#lets remind ourselves of our variables
df.head()
# Out:
#      id  host_id neighbourhood_group       neighbourhood  latitude  longitude  \
# 0  2595     2845           Manhattan             Midtown  40.75356  -73.98559
# 1  3831     4869            Brooklyn  Bedford-Stuyvesant  40.68494  -73.95765
# 2  5121     7356            Brooklyn  Bedford-Stuyvesant  40.68535  -73.95512
# 3  5136     7378            Brooklyn         Sunset Park  40.66265  -73.99454
# 4  5178     8967           Manhattan             Midtown  40.76457  -73.98317
#
#          room_type  accommodates  bathrooms  bedrooms  beds  price  \
# 0  Entire home/apt             2        NaN       NaN   1.0    150
# 1  Entire home/apt             3        NaN       1.0   3.0     79
# 2     Private room             2        NaN       1.0   1.0     60
# 3  Entire home/apt             4        NaN       2.0   2.0    175
# 4     Private room             2        NaN       1.0   1.0     61
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0              30                 48  2019-11-04               0.34
# 1               1                403  2021-05-04               5.16
# 2              30                 50  2016-06-05               0.56
# 3              21                  1  2014-01-02               0.01
# 4               2                474  2020-09-25               3.61
#
#    calculated_host_listings_count  availability_365  review_scores
# 0                               3             308.0           4.70
# 1                               1             208.0           4.46
# 2                               1             365.0           4.52
# 3                               1             134.0           5.00
# 4                               1             246.0           4.19

# %%
room_accommodates = pivot_count(df, "room_type","accommodates")
room_accommodates
# Out:
# accommodates       0       1       2       3       4       5       6      7   \
# room_type
# Entire home/apt   NaN   497.0  6710.0  2985.0  4754.0  1408.0  1588.0  303.0
# Hotel room       23.0     3.0   166.0    15.0    58.0     1.0    11.0    NaN
# Private room      NaN  5301.0  9417.0   622.0   606.0    71.0    74.0   14.0
# Shared room       NaN   356.0   183.0    58.0    25.0     6.0     3.0    NaN
#
# accommodates        8     9      10    11    12    13    14   15    16
# room_type
# Entire home/apt  464.0  56.0  167.0  30.0  79.0  21.0  16.0  8.0  79.0
# Hotel room         1.0   NaN    NaN   NaN   NaN   NaN   NaN  NaN   NaN
# Private room      27.0   3.0   10.0   2.0   6.0   1.0   2.0  3.0  14.0
# Shared room        1.0   NaN    1.0   NaN   1.0   1.0   NaN  NaN   2.0

# %%
# which neighbourhood_groups have the greatest number of choices for accommodating very large groups?
pivot_count(df, "neighbourhood_group","accommodates")
# Out:
# accommodates           0       1       2       3       4      5      6   \
# neighbourhood_group
# Bronx                 NaN   208.0   440.0    94.0   133.0   42.0   37.0
# Brooklyn              3.0  2449.0  6495.0  1247.0  2158.0  609.0  728.0
# Manhattan            20.0  2346.0  7270.0  1929.0  2544.0  665.0  696.0
# Queens                NaN  1103.0  2155.0   388.0   560.0  151.0  194.0
# Staten Island         NaN    51.0   116.0    22.0    48.0   19.0   21.0
#
# accommodates            7      8     9     10    11    12    13   14   15  \
# neighbourhood_group
# Bronx                 11.0   12.0   2.0   9.0   3.0   6.0   NaN  1.0  2.0
# Brooklyn             131.0  236.0  21.0  84.0   9.0  24.0   5.0  5.0  5.0
# Manhattan            117.0  160.0  21.0  52.0  12.0  34.0   5.0  9.0  2.0
# Queens                56.0   74.0  15.0  30.0   6.0  19.0  13.0  3.0  2.0
# Staten Island          2.0   11.0   NaN   3.0   2.0   3.0   NaN  NaN  NaN
#
# accommodates           16
# neighbourhood_group
# Bronx                 3.0
# Brooklyn             44.0
# Manhattan            31.0
# Queens               16.0
# Staten Island         1.0

# %%
# play around with some options. how about neighbourhood_group and price
pivot_count(df, "neighbourhood_group","price")

#any thoughts?
# Out:
# price                0      1      5      10     11     14     15     16     \
# neighbourhood_group
# Bronx                  1.0    NaN    NaN    NaN    1.0    NaN    NaN    1.0
# Brooklyn               5.0    NaN    1.0    3.0    NaN    1.0    2.0    NaN
# Manhattan             32.0    1.0    NaN    2.0    NaN    NaN    1.0    NaN
# Queens                 NaN    NaN    NaN    2.0    1.0    1.0    NaN    1.0
# Staten Island          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# price                17     18     ...  6000   6143   6429   6500   7000   \
# neighbourhood_group                ...
# Bronx                  NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
# Brooklyn               1.0    6.0  ...    NaN    1.0    1.0    1.0    NaN
# Manhattan              1.0    1.0  ...    4.0    NaN    NaN    1.0    1.0
# Queens                 1.0    NaN  ...    NaN    NaN    NaN    NaN    NaN
# Staten Island          NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
#
# price                7314   9000   9990   9999   10000
# neighbourhood_group
# Bronx                  NaN    NaN    NaN    NaN    NaN
# Brooklyn               NaN    NaN    NaN    NaN    1.0
# Manhattan              1.0    NaN    1.0    6.0    4.0
# Queens                 NaN    1.0    NaN    NaN    2.0
# Staten Island          NaN    NaN    NaN    NaN    NaN
#
# [5 rows x 828 columns]

# %%
# observations - not the best method to use with numerical variables (toooooooo many options!)
#errrrr how can we have properties that cost $0 I would definitely stay there. 

# let's check this ... 
df[df.price <10]
# Out:
#              id    host_id neighbourhood_group       neighbourhood   latitude  \
# 524      299062     236421           Manhattan     Upper East Side  40.774330
# 777      550653    2706505            Brooklyn     Windsor Terrace  40.660140
# 26431  40560656  273324213            Brooklyn        Williamsburg  40.720960
# 27343  41740615  268417148           Manhattan             Midtown  40.744590
# 27383  41792753  197053492           Manhattan  Financial District  40.706510
# 27598  42065543  307634016           Manhattan             Midtown  40.744440
# 27599  42065545  310429455           Manhattan             Midtown  40.759170
# 27600  42065547  308721299           Manhattan      Hell's Kitchen  40.764040
# 27601  42065555  309714886            Brooklyn        Williamsburg  40.715230
# 27602  42065562  307633956           Manhattan  Financial District  40.709580
# 27603  42065563  309772430               Bronx          Mott Haven  40.815130
# 27604  42065564  314151200           Manhattan  Financial District  40.704620
# 27605  42065568  310437425           Manhattan         Two Bridges  40.712220
# 27725  42228997  314197504           Manhattan     Lower East Side  40.721860
# 27751  42279170  264478123           Manhattan                SoHo  40.721270
# 27752  42279171  265458818           Manhattan           Chinatown  40.716100
# 27818  42384501  262458398           Manhattan             Chelsea  40.747930
# 27819  42384530  265195377           Manhattan    Theater District  40.755420
# 28263  42830099  300800542           Manhattan                SoHo  40.726380
# 28453  43035720  318559292           Manhattan             Midtown  40.750280
# 28509  43078550  334334264           Manhattan            Kips Bay  40.740970
# 28510  43078552  342053968           Manhattan     Lower East Side  40.722140
# 28626  43205598  335389657           Manhattan             Midtown  40.764480
# 28661  43247386  335072254           Manhattan      Hell's Kitchen  40.767560
# 28662  43247472  324955773           Manhattan             Midtown  40.760850
# 28663  43247631  318788301           Manhattan      Hell's Kitchen  40.761750
# 29820  44567521  360662584           Manhattan        East Village  40.727430
# 30018  45063489  363632751           Manhattan             Midtown  40.761400
# 30533  45494997  304077493           Manhattan    Theater District  40.759130
# 30920  45789481  371218844            Brooklyn        Williamsburg  40.721600
# 30980  45841514  371644174           Manhattan         Murray Hill  40.750920
# 31130  45985185  372762243           Manhattan      Hell's Kitchen  40.761331
# 31213  46059074  373324108           Manhattan    Theater District  40.762368
# 31250  46087899  373522899            Brooklyn        Williamsburg  40.721210
# 31432  46251446  374516933           Manhattan     Lower East Side  40.719732
# 31520  46336133  375044940           Manhattan             Chelsea  40.755322
# 31963  46723973  376877842           Manhattan      Hell's Kitchen  40.765708
# 33374  48089897  261016212            Brooklyn  Bedford-Stuyvesant  40.696787
# 33731  48325676  390077597           Manhattan     Upper West Side  40.781629
# 33841  48417136  390810530           Manhattan             Midtown  40.746836
#
#        longitude     room_type  accommodates  bathrooms  bedrooms  beds  \
# 524   -73.953390  Private room             2        NaN       1.0   1.0
# 777   -73.983110  Private room             2        NaN       1.0   2.0
# 26431 -73.958600    Hotel room             2        NaN       NaN   NaN
# 27343 -73.985740    Hotel room             4        NaN       NaN   NaN
# 27383 -74.007770    Hotel room             6        NaN       NaN   NaN
# 27598 -73.989200    Hotel room             4        NaN       NaN   NaN
# 27599 -73.969260    Hotel room             4        NaN       NaN   NaN
# 27600 -73.994780    Hotel room             4        NaN       NaN   NaN
# 27601 -73.959080    Hotel room             2        NaN       NaN   NaN
# 27602 -74.008740    Hotel room             4        NaN       NaN   NaN
# 27603 -73.916020    Hotel room             4        NaN       NaN   NaN
# 27604 -74.010270    Hotel room             5        NaN       NaN   NaN
# 27605 -73.992690    Hotel room             0        NaN       NaN   NaN
# 27725 -73.992780    Hotel room             4        NaN       NaN   NaN
# 27751 -73.999410    Hotel room             2        NaN       NaN   NaN
# 27752 -73.995180    Hotel room             6        NaN       NaN   NaN
# 27818 -73.991170    Hotel room             2        NaN       NaN   NaN
# 27819 -73.988080    Hotel room             2        NaN       NaN   NaN
# 28263 -74.008850    Hotel room             0        NaN       NaN   NaN
# 28453 -73.985470    Hotel room             0        NaN       NaN   NaN
# 28509 -73.983390    Hotel room             0        NaN       NaN   NaN
# 28510 -73.988570    Hotel room             0        NaN       NaN   NaN
# 28626 -73.980550    Hotel room             0        NaN       NaN   NaN
# 28661 -73.983120    Hotel room             0        NaN       NaN   NaN
# 28662 -73.969380    Hotel room             0        NaN       NaN   NaN
# 28663 -73.988200    Hotel room             0        NaN       NaN   NaN
# 29820 -73.991360    Hotel room             0        NaN       NaN   NaN
# 30018 -73.974610    Hotel room             0        NaN       NaN   NaN
# 30533 -73.983770    Hotel room             0        NaN       NaN   NaN
# 30920 -73.958900    Hotel room             0        NaN       NaN   NaN
# 30980 -73.980050    Hotel room             0        NaN       NaN   NaN
# 31130 -73.989026    Hotel room             0        NaN       NaN   NaN
# 31213 -73.985676    Hotel room             0        NaN       NaN   NaN
# 31250 -73.957209    Hotel room             0        NaN       NaN   NaN
# 31432 -73.993996    Hotel room             0        NaN       NaN   NaN
# 31520 -74.001772    Hotel room             0        NaN       NaN   NaN
# 31963 -73.995575    Hotel room             0        NaN       NaN   NaN
# 33374 -73.958005    Hotel room             0        NaN       NaN   NaN
# 33731 -73.982004    Hotel room             0        NaN       NaN   NaN
# 33841 -73.982699    Hotel room             0        NaN       NaN   NaN
#
#        price  minimum_nights  number_of_reviews last_review  \
# 524        1              30                  0         NaN
# 777        5              30                  6  2018-09-30
# 26431      0               1                 48  2021-05-03
# 27343      0               1                 27  2021-04-25
# 27383      0               1                509  2021-05-30
# 27598      0               1                153  2021-06-02
# 27599      0              30                  0         NaN
# 27600      0              30                  4  2021-05-17
# 27601      0              30                  1  2020-03-18
# 27602      0              30                 87  2021-06-04
# 27603      0              30                  0         NaN
# 27604      0               1                 11  2021-05-30
# 27605      0              30                  0         NaN
# 27725      0              30                  0         NaN
# 27751      0              30                  8  2020-07-02
# 27752      0               1                166  2021-06-01
# 27818      0               1                 68  2021-05-08
# 27819      0              30                 10  2020-01-13
# 28263      0              30                 18  2021-03-14
# 28453      0              30                  0         NaN
# 28509      0              30                  0         NaN
# 28510      0               1                 57  2021-05-19
# 28626      0               1                  9  2020-12-27
# 28661      0               1                  0         NaN
# 28662      0              30                 24  2021-05-02
# 28663      0              30                  0         NaN
# 29820      0               1                  3  2021-04-17
# 30018      0               1                  0         NaN
# 30533      0               1                148  2020-03-14
# 30920      0               1                  5  2021-04-03
# 30980      0               1                  0         NaN
# 31130      0               1                  5  2021-04-18
# 31213      0               1                 55  2021-05-17
# 31250      0               1                  0         NaN
# 31432      0               1                 34  2021-05-20
# 31520      0               1                  0         NaN
# 31963      0               1                  0         NaN
# 33374      0               1                  0         NaN
# 33731      0               1                  0         NaN
# 33841      0               1                  1  2021-05-09
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 524                  NaN                               2        106.396298
# 777                 0.16                               1          0.000000
# 26431               2.34                               1          0.000000
# 27343               1.39                               1          0.000000
# 27383              14.18                               9          0.000000
# 27598              21.06                               1          0.000000
# 27599                NaN                               1          0.000000
# 27600               0.47                               1          0.000000
# 27601               0.07                               1          0.000000
# 27602              12.03                               1          0.000000
# 27603                NaN                               1          0.000000
# 27604               1.03                               9          0.000000
# 27605                NaN                               1          0.000000
# 27725                NaN                               1          0.000000
# 27751               0.37                               5          0.000000
# 27752               7.58                               6          0.000000
# 27818               3.34                               1          0.000000
# 27819               0.48                               3          0.000000
# 28263               0.94                               1          0.000000
# 28453                NaN                               1          0.000000
# 28509                NaN                               1          0.000000
# 28510               4.14                               1          0.000000
# 28626               1.13                               1          0.000000
# 28661                NaN                               1          0.000000
# 28662               1.61                               1          0.000000
# 28663                NaN                               1          0.000000
# 29820               0.61                               1          0.000000
# 30018                NaN                               1          0.000000
# 30533               8.01                               1          0.000000
# 30920               1.79                               1          0.000000
# 30980                NaN                               1          0.000000
# 31130               0.86                               1          0.000000
# 31213               9.94                               1          0.000000
# 31250                NaN                               1          0.000000
# 31432               7.73                               1          0.000000
# 31520                NaN                               1          0.000000
# 31963                NaN                               1          0.000000
# 33374                NaN                               1          0.000000
# 33731                NaN                               1          0.000000
# 33841               1.00                               1          0.000000
#
#        review_scores
# 524              NaN
# 777             4.80
# 26431           4.71
# 27343           4.19
# 27383           4.89
# 27598           4.61
# 27599            NaN
# 27600           4.25
# 27601           5.00
# 27602           4.82
# 27603            NaN
# 27604           4.27
# 27605            NaN
# 27725            NaN
# 27751           5.00
# 27752           4.57
# 27818           4.46
# 27819           4.20
# 28263           4.53
# 28453            NaN
# 28509            NaN
# 28510           3.93
# 28626           4.11
# 28661            NaN
# 28662           4.17
# 28663            NaN
# 29820           4.33
# 30018            NaN
# 30533           3.67
# 30920           4.40
# 30980            NaN
# 31130           4.80
# 31213           4.75
# 31250            NaN
# 31432           4.82
# 31520            NaN
# 31963            NaN
# 33374            NaN
# 33731            NaN
# 33841           5.00

# %%
#Remember - cleaning data is not linear. Lets fix that 
df = df[df.price > 10]

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="700"/>
# </div>

# %% [markdown]
# ## <font color='#eb3483'> Categorical Variable Means </font>

# %%
#check out average price per room type and property type
df.groupby("room_type")["price"].mean().plot.barh()
# Out:
# <AxesSubplot:ylabel='room_type'>

# %%
#plot mean price of properties per neighbourhood_group 
df.groupby("neighbourhood_group")["price"].mean().plot.barh()
# Out:
# <AxesSubplot:ylabel='neighbourhood_group'>

# %%
#plot mean price of properties per neighbourhood 
plt.figure(figsize=(13,30))
df.groupby("neighbourhood")["price"].mean().plot.barh()
# Out:
# <AxesSubplot:ylabel='neighbourhood'>

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

categorical_variables = df.select_dtypes(
    ['object', 'category']).columns.tolist()

numerical_variables = df.select_dtypes(include=np.number) # different way of doing the above. 
#There is almnost always more than 1 way to skin a code

def means_by_category(col_group, col_calc):
    df.groupby(col_group)[col_calc].mean().nlargest(10).plot(kind='barh', figsize=(10,10))
    sns.mpl.pyplot.xlabel('Mean values for variable {}'.format(col_calc))

interact(means_by_category, col_group=categorical_variables, col_calc=numerical_variables);
# Out:
# interactive(children=(Dropdown(description='col_group', options=('neighbourhood_group', 'neighbourhood', 'room…

# %%
#interactive widgets are great for playing around with your data
#But if you are sharing your notebook and you want someone else to follow your logic - 
#good idea to rather code the options you are interested in.

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="700"/>
# </div>

# %% [markdown]
# ##  <font color='#eb3483'> Correlations </font>

# %% [markdown]
# An easy way to visually see all correlations is by using the `pairplot` function we learned with seaborn. However, this only works when there aren't many columns.
#
# **Note** Scatterplot matrices computation are a bit heavy, this might take a while in your computer.

# %%
#sns.pairplot(df) #- not going to run this now but try it out for yourself later

# %%
# Do more expensive rentals get better ratings
#Is there a relationship between price and review_score_rating?

sns.regplot("price", "review_scores", data=df);

# %%
#try out any others that interest you

# %% [markdown]
# <hr>

# %% [markdown]
# Once we have finished the analyisis, the last step is to compile all of our findings and put it on one document. This document serves 2 purposes:
#
# - It helps inform people in the future of our findings. That person might even ourselves!.
# - Facilitate the replication of the analysis by other Data Scientists.
#
# Let's summarize all the work we've done!
#
# # <font color='#eb3483'> Analysis Conclusion </font>
#
# ### <font color='#eb3483'> Description </font>
#
# Describe the data set. What it is. Where it comes from. Maybe the time period it covers. etc.
#
#
#
# ### <font color='#eb3483'> Data dictionary </font>
#
# The variables that exist on the dataset are:
#
# ```
# * xxx (categorical)
# etc.
# ```
#
# ### <font color='#eb3483'> Data Processing </font>
#
# - copy from previously
#
# ### <font color='#eb3483'> Variable Exploration Description <font color='#eb3483'>
# - copy from previously
#
#
# ### <font color='#eb3483'> Comparisons </font>
#
# - list any insights that stood out for you here.
#
#
# ### <font color='#eb3483'> Conclusions </font>
# - list any major conclusions

# %% [markdown]
# <hr>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <font color='#eb3483'> 5. Pandas Profiling </font>

# %% [markdown]
# To save us some trouble - pandas has a very nifty function that helps with some EDA
#
# An awesome package that you can check-out here: https://github.com/JosPolfliet/pandas-profiling
#
# Here is a great example of Pandas profiling https://medium.com/analytics-vidhya/pandas-profiling-5ecd0b977ecd
#
# (warning it can be buggy and hard to get working but if you do it works well)
#
# To install you can run `conda install -c conda-forge pandas-profiling` - in terminal

# %% [markdown]
# With pandas-profiling we can generate a report from a pandas dataframe that provides a ton of information about the data

# %%
#import pandas_profiling

# %%
#df = pd.read_csv("data/airbnb_processed.csv")

# %%
#not going to run as it takes quite a bit of time.
#report = pandas_profiling.ProfileReport(df)

# %%
#report

# %% [markdown]
# We can even save the report as an html, this is very useful when sharing with a colleague

# %%
#type(report)
#report.to_file(output_file = 'profiling_report.html')
