# %% [markdown]
# # <font color='#eb3483'> Exploratory Data Analysis - Part 2 </font>

# %% [markdown]
# Let's remind ourselves of where we left off

# %% [markdown]
# ### <font color='#eb3483'> Data processing steps </font>
# - There are xxx duplicate rows (we have removed them)
# - The variables `xxx, xxx, xxx and xxx` have missing values - what did we do with these?
# - The categorical variable `xxx, xxx` has a dominant class (65% of xxx are xxx, etc)
# - There are outliers in the variables `xxx and xxx` - what did we do with these?

# %% [markdown]
# ### <font color='#eb3483'> Entity Description <font color='#eb3483'>
#
# Here we describe the possible entities(groupings) that we can break our dataset into, this will help us think of different ways to slice and group the dataset in further steps.
#
# - neighbourhood or zipcode. City was almost all Cape Town, so not very informative for differentiation (ie low cardinality).
# - Most common zipcode is 8001 and ward is 115.
# - property_type - whole houses and apartments is the most common type.
# - room_type -> a lot of entire apartments and shared rooms.
# - bed type -> predominently real beds. Not much value in this variable.
# - accommodates - > good range of sizes of properties.

# %%
# Importing the required packages here

import numpy as np
import pandas as pd
import seaborn as sns
import ast, json

from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### <font color='#eb3483'>  Load our data </font>
# After each step it is important to save the dataset with a different name (so we dont modify the original).

# %%
df = pd.read_csv("data/airbnb_processed.csv")
df.head()
# Out:
#       id  host_id  host_since neighbourhood              city zipcode  \
# 0   3191     3754  2008-10-21       Ward 57  Southern Suburbs    7700
# 1  15007    59072  2009-12-01       Ward 23         Cape Town    7441
# 2  15068    59318  2009-12-02       Ward 23         Cape Town    7441
# 3  15077    59342  2009-12-02        Ward 4         Cape Town    7441
# 4  15180    59663  2009-12-03       Ward 83         Cape Town    7139
#
#    latitude  longitude property_type        room_type  ...  bathrooms  \
# 0 -33.94739   18.47600    Guesthouse  Entire home/apt  ...        1.0
# 1 -33.80001   18.46063         House  Entire home/apt  ...        3.0
# 2 -33.78799   18.46082     Apartment  Entire home/apt  ...        2.0
# 3 -33.85812   18.49043     Apartment     Private room  ...        1.5
# 4 -34.11124   18.82349     Apartment  Entire home/apt  ...        1.0
#
#    bedrooms  beds  bed_type square_feet  price  cleaning_fee  \
# 0       1.0   1.0  Real Bed         NaN    819     261.00000
# 1       3.0   4.0  Real Bed         NaN   2050     850.00000
# 2       3.0   5.0  Real Bed         NaN   2804     650.00000
# 3       1.0   2.0  Real Bed         NaN   1620     339.42485
# 4       1.0   1.0  Real Bed         NaN    575     200.00000
#
#    number_of_reviews  review_scores_rating  price_usd
# 0                 54                  97.0       55.0
# 1                 27                  97.0      137.0
# 2                  0                   NaN      187.0
# 3                  5                 100.0      108.0
# 4                  0                   NaN       38.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <font color='#eb3483'> 4. Digging into patterns </font>
#
# The final stage of our EDA journey is going to be to look at the relationship between variables in our data. The goal of this stage is to get a better understanding of how our data interacts with each other.

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="700"/>
# </div>

# %% [markdown]
# ## <font color='#eb3483'> Multiple group counts </font>

# %%
def pivot_count(df, rows, columns): # this just makes a function that does a pivotcount for us with different variables.
    df_pivot = df.pivot_table(values="id", # could be any column, since we are just counting rows 
                              index=rows, 
                              columns=columns, 
                              aggfunc=np.size
                             ).dropna(axis=0, how='all')
    return df_pivot

# %%
df.head()
# Out:
#       id  host_id  host_since neighbourhood              city zipcode  \
# 0   3191     3754  2008-10-21       Ward 57  Southern Suburbs    7700
# 1  15007    59072  2009-12-01       Ward 23         Cape Town    7441
# 2  15068    59318  2009-12-02       Ward 23         Cape Town    7441
# 3  15077    59342  2009-12-02        Ward 4         Cape Town    7441
# 4  15180    59663  2009-12-03       Ward 83         Cape Town    7139
#
#    latitude  longitude property_type        room_type  ...  bathrooms  \
# 0 -33.94739   18.47600    Guesthouse  Entire home/apt  ...        1.0
# 1 -33.80001   18.46063         House  Entire home/apt  ...        3.0
# 2 -33.78799   18.46082     Apartment  Entire home/apt  ...        2.0
# 3 -33.85812   18.49043     Apartment     Private room  ...        1.5
# 4 -34.11124   18.82349     Apartment  Entire home/apt  ...        1.0
#
#    bedrooms  beds  bed_type square_feet  price  cleaning_fee  \
# 0       1.0   1.0  Real Bed         NaN    819     261.00000
# 1       3.0   4.0  Real Bed         NaN   2050     850.00000
# 2       3.0   5.0  Real Bed         NaN   2804     650.00000
# 3       1.0   2.0  Real Bed         NaN   1620     339.42485
# 4       1.0   1.0  Real Bed         NaN    575     200.00000
#
#    number_of_reviews  review_scores_rating  price_usd
# 0                 54                  97.0       55.0
# 1                 27                  97.0      137.0
# 2                  0                   NaN      187.0
# 3                  5                 100.0      108.0
# 4                  0                   NaN       38.0
#
# [5 rows x 21 columns]

# %%
room_accommodates = pivot_count(df, "room_type","accommodates")
room_accommodates
# Out:
# accommodates        1       2      3       4      5       6      7       8   \
# room_type
# Entire home/apt  139.0  5797.0  989.0  5159.0  847.0  2700.0  407.0  1362.0
# Hotel room        12.0   232.0   36.0    77.0    5.0    31.0    1.0     7.0
# Private room     711.0  3669.0  233.0   342.0   34.0    71.0   16.0    31.0
# Shared room       52.0    46.0    5.0    11.0    4.0     5.0    NaN     4.0
#
# accommodates        9      10    11     12    13    14   15    16   18   20  \
# room_type
# Entire home/apt  106.0  496.0  26.0  165.0  17.0  48.0  5.0  49.0  1.0  1.0
# Hotel room         NaN    2.0   NaN    1.0   NaN   1.0  NaN   3.0  NaN  NaN
# Private room      10.0   21.0   3.0   16.0   2.0   9.0  3.0  41.0  NaN  NaN
# Shared room        NaN    5.0   NaN    4.0   NaN   NaN  NaN   2.0  NaN  NaN
#
# accommodates      40
# room_type
# Entire home/apt  NaN
# Hotel room       NaN
# Private room     1.0
# Shared room      NaN

# %%
# which neighbourhoods have places that accommodate the greatest number of guests
wards_accommodates = pivot_count(df, "property_type","accommodates")
wards_accommodates
# Out:
# accommodates               1       2      3       4      5       6      7   \
# property_type
# Aparthotel                NaN    16.0    2.0     8.0    NaN     4.0    NaN
# Apartment               310.0  4442.0  642.0  3230.0  261.0   667.0   25.0
# Barn                      1.0     NaN    NaN     1.0    NaN     1.0    NaN
# Bed and breakfast        30.0   419.0   52.0    57.0    8.0     7.0    3.0
# Boat                      NaN     5.0    NaN     NaN    NaN     NaN    NaN
# Boutique hotel            5.0   143.0    8.0     4.0    NaN     1.0    NaN
# Bungalow                  4.0    51.0    4.0    34.0    7.0    25.0    3.0
# Bus                       NaN     1.0    NaN     NaN    NaN     NaN    NaN
# Cabin                     1.0    16.0    5.0     2.0    NaN     4.0    NaN
# Camper/RV                 NaN     7.0    2.0     NaN    2.0     NaN    NaN
# Casa particular (Cuba)    1.0     2.0    NaN     NaN    NaN     NaN    NaN
# Castle                    1.0     NaN    NaN     NaN    NaN     1.0    NaN
# Cave                      1.0     NaN    NaN     NaN    NaN     NaN    NaN
# Chalet                    NaN    24.0    4.0    12.0    2.0     6.0    NaN
# Condominium              12.0   211.0   38.0   236.0   30.0    47.0    3.0
# Cottage                   7.0   165.0   36.0   146.0   33.0    52.0    4.0
# Dome house                NaN     5.0    NaN     NaN    NaN     NaN    NaN
# Dorm                      NaN     NaN    NaN     1.0    NaN     1.0    NaN
# Earth house               3.0     5.0    NaN     3.0    NaN     NaN    NaN
# Farm stay                 NaN    30.0    4.0    12.0    NaN     3.0    NaN
# Guest suite              51.0  1066.0  123.0   207.0   21.0    26.0    1.0
# Guesthouse               26.0   653.0   69.0   149.0   17.0    28.0    4.0
# Heritage hotel (India)    NaN     1.0    NaN     NaN    NaN     NaN    NaN
# Hostel                   24.0    36.0    3.0    11.0    NaN     5.0    NaN
# Hotel                     2.0    21.0    1.0     2.0    NaN     2.0    NaN
# House                   360.0  1695.0  163.0  1043.0  426.0  1530.0  333.0
# Hut                       NaN     3.0    1.0     NaN    NaN     NaN    NaN
# Island                    NaN     NaN    1.0     NaN    NaN     NaN    NaN
# Lighthouse                NaN     1.0    NaN     1.0    NaN     NaN    NaN
# Loft                      9.0   199.0   40.0    46.0    8.0    15.0    NaN
# Nature lodge              NaN     8.0    2.0     2.0    NaN     1.0    NaN
# Other                     5.0    59.0    4.0    19.0    4.0     5.0    NaN
# Resort                    NaN     3.0    NaN     3.0    NaN     NaN    NaN
# Serviced apartment        4.0   213.0   24.0   130.0   15.0    59.0    1.0
# Tent                      NaN     1.0    NaN     NaN    NaN     NaN    NaN
# Tiny house                1.0    23.0    2.0     7.0    NaN     NaN    NaN
# Tipi                      NaN     1.0    NaN     1.0    NaN     NaN    NaN
# Townhouse                47.0   118.0   31.0   183.0   38.0   122.0   10.0
# Treehouse                 NaN     2.0    NaN     NaN    NaN     NaN    NaN
# Vacation home             NaN     NaN    NaN     NaN    NaN     1.0    NaN
# Villa                     9.0    99.0    2.0    39.0   18.0   193.0   37.0
# Yurt                      NaN     NaN    NaN     NaN    NaN     1.0    NaN
#
# accommodates               8     9      10    11    12   13    14   15    16  \
# property_type
# Aparthotel                NaN   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Apartment                66.0   2.0   15.0   1.0   2.0  NaN   1.0  NaN   2.0
# Barn                      NaN   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Bed and breakfast         9.0   1.0    8.0   1.0   4.0  1.0   3.0  2.0  20.0
# Boat                      1.0   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Boutique hotel            NaN   NaN    NaN   NaN   1.0  NaN   2.0  1.0   6.0
# Bungalow                 10.0   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Bus                       NaN   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Cabin                     NaN   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Camper/RV                 NaN   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Casa particular (Cuba)    NaN   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Castle                    NaN   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Cave                      NaN   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Chalet                    1.0   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Condominium               7.0   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Cottage                   8.0   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Dome house                NaN   NaN    2.0   NaN   1.0  NaN   NaN  NaN   NaN
# Dorm                      NaN   1.0    1.0   NaN   NaN  NaN   NaN  NaN   NaN
# Earth house               NaN   NaN    NaN   NaN   1.0  NaN   NaN  NaN   NaN
# Farm stay                 3.0   NaN    3.0   NaN   1.0  1.0   NaN  NaN   1.0
# Guest suite               4.0   1.0    2.0   NaN   NaN  NaN   NaN  NaN   2.0
# Guesthouse                4.0   1.0    4.0   NaN   1.0  1.0   3.0  NaN   8.0
# Heritage hotel (India)    NaN   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Hostel                    2.0   1.0    3.0   NaN   3.0  NaN   NaN  NaN   3.0
# Hotel                     NaN   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# House                   958.0  85.0  287.0  18.0  78.0  8.0  24.0  2.0  23.0
# Hut                       NaN   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Island                    NaN   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Lighthouse                NaN   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Loft                      1.0   NaN    NaN   1.0   NaN  NaN   NaN  NaN   1.0
# Nature lodge              NaN   NaN    NaN   NaN   NaN  NaN   1.0  NaN   NaN
# Other                     1.0   NaN    NaN   NaN   NaN  1.0   NaN  NaN   1.0
# Resort                    1.0   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Serviced apartment       12.0   1.0    2.0   NaN   1.0  NaN   1.0  NaN   1.0
# Tent                      NaN   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Tiny house                1.0   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Tipi                      NaN   NaN    NaN   NaN   2.0  NaN   NaN  NaN   NaN
# Townhouse                24.0   1.0    5.0   1.0   1.0  NaN   NaN  3.0   2.0
# Treehouse                 NaN   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Vacation home             NaN   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
# Villa                   291.0  22.0  192.0   7.0  90.0  7.0  23.0  NaN  25.0
# Yurt                      NaN   NaN    NaN   NaN   NaN  NaN   NaN  NaN   NaN
#
# accommodates             18   20   40
# property_type
# Aparthotel              NaN  NaN  NaN
# Apartment               NaN  NaN  NaN
# Barn                    NaN  NaN  NaN
# Bed and breakfast       NaN  NaN  1.0
# Boat                    NaN  NaN  NaN
# Boutique hotel          NaN  NaN  NaN
# Bungalow                NaN  NaN  NaN
# Bus                     NaN  NaN  NaN
# Cabin                   NaN  NaN  NaN
# Camper/RV               NaN  NaN  NaN
# Casa particular (Cuba)  NaN  NaN  NaN
# Castle                  NaN  NaN  NaN
# Cave                    NaN  NaN  NaN
# Chalet                  NaN  NaN  NaN
# Condominium             NaN  NaN  NaN
# Cottage                 NaN  NaN  NaN
# Dome house              NaN  NaN  NaN
# Dorm                    NaN  NaN  NaN
# Earth house             NaN  NaN  NaN
# Farm stay               NaN  NaN  NaN
# Guest suite             NaN  NaN  NaN
# Guesthouse              NaN  NaN  NaN
# Heritage hotel (India)  NaN  NaN  NaN
# Hostel                  NaN  NaN  NaN
# Hotel                   NaN  NaN  NaN
# House                   1.0  NaN  NaN
# Hut                     NaN  NaN  NaN
# Island                  NaN  NaN  NaN
# Lighthouse              NaN  NaN  NaN
# Loft                    NaN  NaN  NaN
# Nature lodge            NaN  NaN  NaN
# Other                   NaN  NaN  NaN
# Resort                  NaN  NaN  NaN
# Serviced apartment      NaN  NaN  NaN
# Tent                    NaN  NaN  NaN
# Tiny house              NaN  NaN  NaN
# Tipi                    NaN  NaN  NaN
# Townhouse               NaN  NaN  NaN
# Treehouse               NaN  NaN  NaN
# Vacation home           NaN  NaN  NaN
# Villa                   NaN  1.0  NaN
# Yurt                    NaN  NaN  NaN

# %%
# play around with some options.

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="700"/>
# </div>

# %% [markdown]
# ## <font color='#eb3483'> Categorical Variable Means </font>

# %%
#check out average price per room type and property type
df.groupby("property")["price"].mean().plot.barh()
# Out:
# <AxesSubplot:ylabel='room_type'>

# %%
#plot mean price of properties per property type
plt.figure(figsize=(13,13))

# %%
# WHAT! the avergae price of dorm room is R70 000 ($3500 ish!?!) # No way we must have missed something there.
# maybe we need to look at outliers per room type rather than overall?
# A reminder that EDA is not a linear process. You will go back and forth A LOT

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

categorical_variables = df.select_dtypes(
    ['object', 'category']).columns.tolist()

numerical_variables = df.select_dtypes(include=np.number) # different way of doing the above. 
#There is almnost always more than 1 way to skin a code

def means_by_category(col_group, col_calc):
    df.groupby(col_group)[col_calc].mean().nlargest(10).plot(kind='barh', figsize=(10,10))
    sns.mpl.pyplot.xlabel('Mean values for variable {}'.format(col_calc))

interact(means_by_category, col_group=categorical_variables, col_calc=numerical_variables);

# %%
#interactive widgets are great for playing around with your data
#But if you are sharing your notebook and you want someone else to follow your logic - 
#good idea to rather code the options you are interested in.

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="700"/>
# </div>

# %% [markdown]
# ##  <font color='#eb3483'> Correlations </font>

# %% [markdown]
# An easy way to visually see all correlations is by using the `pairplot` function we learned with seaborn. However, this only works when there aren't many columns.
#
# **Note** Scatterplot matrices computation are a bit heavy, this might take a while in your computer.

# %%
#sns.pairplot(df) #- not going to run this now but try it out for yourself later

# %%
# Do more expensive rentals get better ratings
#Is there a relationship between price and review_score_rating?

sns.regplot("price", "review_scores_rating", data=df);

# %%
#try out any others that interest you

# %% [markdown]
# <hr>

# %% [markdown]
# Once we have finished the analyisis, the last step is to compile all of our findings and put it on one document. This document serves 2 purposes:
#
# - It helps inform people in the future of our findings. That person might even ourselves!.
# - Facilitate the replication of the analysis by other Data Scientists.
#
# Let's summarize all the work we've done!
#
# # <font color='#eb3483'> Analysis Conclusion </font>
#
# ### <font color='#eb3483'> Description </font>
#
# Describe the data set. What it is. Where it comes from. Maybe the time period it covers. etc.
#
#
#
# ### <font color='#eb3483'> Data dictionary </font>
#
# The variables that exist on the dataset are:
#
# ```
# * xxx (categorical)
# etc.
# ```
#
# ### <font color='#eb3483'> Data Processing </font>
#
# - copy from previously
#
# ### <font color='#eb3483'> Variable Exploration Description <font color='#eb3483'>
# - copy from previously
#
#
# ### <font color='#eb3483'> Comparisons </font>
#
# - list any insights that stood out for you here.
#
#
# ### <font color='#eb3483'> Conclusions </font>
# - list any major conclusions

# %% [markdown]
# <hr>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <font color='#eb3483'> 5. Pandas Profiling </font>

# %% [markdown]
# To save us some trouble - pandas has a very nifty function that helps with some EDA
#
# An awesome package that you can check-out here: https://github.com/JosPolfliet/pandas-profiling
#
# Here is a great example of Pandas profiling https://medium.com/analytics-vidhya/pandas-profiling-5ecd0b977ecd
#
# (warning it can be buggy and hard to get working but if you do it works well)
#
# To install you can run `conda install -c conda-forge pandas-profiling` - in terminal

# %% [markdown]
# With pandas-profiling we can generate a report from a pandas dataframe that provides a ton of information about the data

# %%
#import pandas_profiling

# %%
#df = pd.read_csv("data/airbnb_processed.csv")

# %%
#not going to run as it takes quite a bit of time.
#report = pandas_profiling.ProfileReport(df)

# %%
#report

# %% [markdown]
# We can even save the report as an html, this is very useful when sharing with a colleague

# %%
#type(report)
#report.to_file(output_file = 'profiling_report.html')
