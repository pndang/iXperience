# %% [markdown]
# # <font color='#eb3483'> GETTING STARTED </font>
#
#
# Welcome to iX Data Analytics
#
#
# This notebook will help to familiarise ourselves with Jupyter notebooks and also learn some python coding basics.

# %% [markdown]
# ### Some navigating in Jupyter Notebooks ...

# %% [markdown]
# ### How do I run a line of code?

# %%
# to run a cell - click the run button above.

# to run a cell hit Control+Enter (windows) or # to run a cell hit Cmd+Enter (mac)
# to run a cell and move to the next cell hit Shift+Enter

print('Hello World!')
print('Wassup Phuuu! Welcome Back!')
# Out:
# Hello World!
# Wassup Phuuu! Welcome Back!

# %% [markdown]
# ### How are you going to learn?
# The only way to learn to code is ... to code.
# So be curious, try things out, experiment. You won't break anything :)

# %%
#here is a simple sum 
print(2+1000000)
11+22+31
# Out:
# 1000002
# 64

# %% [markdown]
# ## <font color='#eb3483'> Two types of cells in Jupyter Notebooks </font>

# %% [markdown]
# ### <font color='#eb3483'> 1) Markdown </font>

# %% [markdown]
# This is a markdown cell. It allows us to write text in our notebook so we can add narratives, information etc
#
# Double click to see the code.
#
# <hr>

# %% [markdown]
# To change the cell type (and other options) you need to be in "command mode". You are in command mode when the colour on the left of your cell is blue and you are in "edit mode" when the colour is green.
#
# To get into command mode you can:
# - hit esc,
# - click the pencil icon on the top right or
# - click next to the line colour on the left of the cell.
#
# Try it in the empty cell below.
#
# To get back to edit mode (green) where you are able to edit the cells
# from command mode (blue) where you specify what kind of cell it should be ... hit enter.

# %% [markdown]
# To change a cell to Markdown. Enter command mode and select markdown from the dropdown menu above or simply hit m.
#
# Try it below. Type what you had for breakfast ...
# 1) click the cell
# 2) change to command mode (push esc)
# 3) change cell into a markdown cell (push m)
# 4) type away ...

# %% [markdown]
# ### iX is the besttt!!

# %% [markdown]
# To view command mode shortcuts - hit h while in command mode

# %% [markdown]
# Once a cell is set to output markdown, you can write text and it will turn into beautiful html. Here is a great markdown [cheatsheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet#code) to keep handy!
#
# **This in bold**
# (double click this cell to see how we generate these effects - to transform to markdown simply run cell as normal
#
# *This in italics*
#
#
#  <font color='#eb3483'> This text is pink </font>
#
#
#
# ### Introduction to Jupyter Header
#
# - Element 1
#   - Element 1.1
#
#
# <hr>

# %%
#adding apicture is really easy. 
#you can just copy and paste and voila

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#try it here

# %% [markdown]
# ![rocket.webp](attachment:rocket.webp)

# %% [markdown]
# ![rocket](https://media.wired.com/photos/59443ccf36ebbc129f7410e0/125:94/w_2375,h_1786,c_limit/Rocket-Art-531752474.jpg)

# %% [markdown]
# Or you can use a web url
# ![kitty](https://i2-prod.mirror.co.uk/incoming/article25609246.ece/ALTERNATES/n615/0_PUSS-IN-BOOTS.jpg)

# %% [markdown]
# How about drag and drop?

# %% [markdown]
# Okay - take 5 mins and play around with the above to get used to it. and try it out

# %% [markdown]
# <hr>
#
# ### <font color='#eb3483'> 2) Code cells </font>

# %%
# code cells are cells where we want to actually do some kind of computation.
# It's often useful to add text in these cells too.
# To remind you what that cell does, 
# or add a note or an explanation to yourself or someone else reading etc.


# But code cells dont like text in them.
heyo. run this cell
# Out:
#   Input In [16]
#     heyo. run this cell
#               ^
# SyntaxError: invalid syntax

# %%
# So we can block helper text from trying to be run by "commenting" out. ie using a #

# This is a comment, python ignores these lines.

# %%
#Python scripts are executed linearly, line after line, top to bottom

print('Hello World!')

print("Second line to print!")
# Out:
# Hello World!
# Second line to print!
# 'Bruv'

# %%
# in python, text (strings), can be defined either with single quotes ' or double quotes "
print('I AM LEARNING PYTHON AND IT ROCKS')

#Write something else
# Out:
# I AM LEARNING PYTHON AND IT ROCKS

# %% [markdown]
# ### A few more helpful tips
#
# When in command mode here are a few handy shortcuts. Hitting:
# - m changes cell to markdown
# - a inserts cell above
# - b inserts cell below
# - dd deletes a cell.
# - z undoes delete cell

# %% [markdown]
# Take 5 mins and try out some code cells. Print some text, try a calculation etc.

# %% [markdown]
# It definitely takes a bit of time to get used to but after the first couple of rounds it will totally start becoming easier and easier!

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="300"/>
# </div>
